# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 11.09.2020
#
# Мягкий дедлайн: 04:59MSK 21.09.2020 (но лучше сдайте пораньше и успейте выспаться)
#
# Жесткий дедлайн: 23:59MSK 24.09.2020

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки pandas и визуализации с помощью matplotlib. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов.
#
# Сдавать задание после жёсткого дедлайна нельзя. При выставлении неполного балла за задание в связи с наличием ошибок на усмотрение проверяющего предусмотрена возможность исправить работу на указанных в ответном письме условиях.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: 12 (минус энное количество баллов за недобор 17 правильных строк для весеннего распределения)

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
print("Hello, world!" + str(2**3))
# Out:
# Hello, world!8

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline  
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем данные:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# Для пользователей Windows: скачайте файл самостоятельно и поместите его в папку с тетрадкой. Или попробуйте один из следующих вариантов:

# %%
# !powershell iwr -outf somefile https://somesite/somefile

# %%
# !pip install wget
# import wget 
# wget.download('https://dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=1', 'end_seminar.xlsx')

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
data = pd.read_excel('end_seminar.xlsx')
data.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# ...

# %% [markdown]
# #### 2. [0.5 балла] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями?

# %%
# Пункт 1
print("Студентов 17-го года: " + str(sum(pd.isnull(data["18_group"]))))
print("Студентов 18-го года: " + str(sum(pd.isnull(data["17_group"]))))

# Пункт 2
print("Cтудентов с одинаковыми перцентлями: " + str(data.loc[data['percentile'].duplicated()].shape[0]))
# Out:
# Студентов 17-го года: 138
# Студентов 18-го года: 223
# Cтудентов с одинаковыми перцентлями: 15

# %% [markdown]
# #### 3. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
nan_series = data.isna().sum()
print("Пропуски по столбцам:")
print(nan_series)
# Out:
# Пропуски по столбцам:
# timestamp          0
# id                 0
# rating             0
# 18_group         138
# is_mi            343
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1           0
# spring_2           0
# spring_3           0
# is_first_time      2
# percentile         0
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Для удобства, воспользуемся циклом ТОЛЬКО ДЛЯ ДЕМОНСТРАЦИИ, не бейте :)

# %%
for name, value in nan_series.iteritems():
    print("В столбце " + name + " обнаружено " + str(value) + " пропущенных значений")
# Out:
# В столбце timestamp обнаружено 0 пропущенных значений
# В столбце id обнаружено 0 пропущенных значений
# В столбце rating обнаружено 0 пропущенных значений
# В столбце 18_group обнаружено 138 пропущенных значений
# В столбце is_mi обнаружено 343 пропущенных значений
# В столбце fall_1 обнаружено 0 пропущенных значений
# В столбце fall_2 обнаружено 0 пропущенных значений
# В столбце fall_3 обнаружено 0 пропущенных значений
# В столбце spring_1 обнаружено 0 пропущенных значений
# В столбце spring_2 обнаружено 0 пропущенных значений
# В столбце spring_3 обнаружено 0 пропущенных значений
# В столбце is_first_time обнаружено 2 пропущенных значений
# В столбце percentile обнаружено 0 пропущенных значений
# В столбце 17_group обнаружено 223 пропущенных значений
# В столбце blended обнаружено 223 пропущенных значений
# В столбце is_ml_student обнаружено 304 пропущенных значений

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых.

# %%
# работаем с числовыми колонками
numeric_columns_labels = data.select_dtypes(include=np.number).columns.to_numpy()
data[numeric_columns_labels] = data[numeric_columns_labels].fillna(0)

# работаем со строковыми колонками
string_columns_labels = data.select_dtypes(include=object).columns.to_numpy()
data[string_columns_labels] = data[string_columns_labels].fillna("")

# %% [markdown]
# Проверим, остались ли пропуски:

# %%
nan_series = data.isna().sum()
print("Пропуски по столбцам:")
print(nan_series)
# Out:
# Пропуски по столбцам:
# timestamp        0
# id               0
# rating           0
# 18_group         0
# is_mi            0
# fall_1           0
# fall_2           0
# fall_3           0
# spring_1         0
# spring_2         0
# spring_3         0
# is_first_time    0
# percentile       0
# 17_group         0
# blended          0
# is_ml_student    0
# dtype: int64

# %% [markdown]
# #### 4. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию.

# %%
filter = lambda data : data["is_first_time"] == "Нет"
print("Количество записей, оставленных не в первый раз: " + str(data.loc[filter].shape[0]))
duplicated = data.loc[data["id"].duplicated()]
print("Количество записей с уже встреченными id: " + str(duplicated[["id", "is_first_time"]].shape[0]))
# Out:
# Количество записей, оставленных не в первый раз: 51
# Количество записей с уже встреченными id: 14

# %% [markdown]
# Странно, что эти два числа не равны. Вероятно, при обработке данных до нас для 37 записей, которые были оставлены не в первые, были стерты "предшествующие" записи
# ¯\_(ツ)_/¯

# %%
data = data.loc[data["id"].duplicated(keep="last") == False]
print("Количество записей после удаления: " + str(data.shape[0]))
# Out:
# Количество записей после удаления: 347

# %% [markdown]
# #### 5. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из курсов собрались студенты с самым высоким средним рейтингом?

# %%
# Пункт 1

data_17_year = data.loc[data["17_group"] != 0]
blended_courses_list = numpy.unique(data_17_year["blended"].values)
print("Список blended-курсов для четверокурсников: " + numpy.array_str(blended_courses_list)[1:-1])
# Out:
# Список blended-курсов для четверокурсников: 'DevOps' 'Введение в дифференциальную геометрию'
#  'Соревновательный анализ данных'

# %%
# Пункт 2
grouped_by_blended_rating = data_17_year.groupby("blended")["rating"]
print("Blended-курс с наибольшим количеством записавшихся студентов: " + str(grouped_by_blended_rating.count().idxmax()))
# Out:
# Blended-курс с наибольшим количеством записавшихся студентов: DevOps

# %%
# Пункт 3
grouped_by_blended_rating_means = grouped_by_blended_rating.mean()
print("Blended-курс с наибольшим средним рейтингом записавшихся студентов: " + str(grouped_by_blended_rating_means.idxmax()))
print("Средний рейтинг: " + str(grouped_by_blended_rating_means.max()))
# Out:
# Blended-курс с наибольшим средним рейтингом записавшихся студентов: Введение в дифференциальную геометрию
# Средний рейтинг: 1210.7333333333333

# %% [markdown]
# #### 6. [1 балл] Выясните, есть ли в данных студенты с абсолютно одинаковыми предпочтениями по всем курсам (не забудьте учесть blended-курсы для четверокурсников). Сколько таких наборов, которые взяли несколько студентов? Выведите их все вместе с количеством выбравших их студентов.

# %%
# your code
courses_columns_labels = ["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3", "blended"]
courses_data = data[courses_columns_labels]
groups_simillar_courses = courses_data.loc[courses_data.duplicated(keep=False)].groupby(courses_columns_labels).size()
groups_simillar_courses
# Out:
# fall_1                                           fall_2                                           fall_3                                           spring_1                                                spring_2                                     spring_3                                     blended
# Statistical Learning Theory                      Анализ неструктурированных данных                Сбор и обработка данных с помощью краудсорсинга  Обучение с подкреплением                                Конфликты и кооперация                       Компьютерное зрение                          DevOps     2
# Байесовские методы машинного обучения            Анализ неструктурированных данных                Глубинное обучение в обработке звука             Обучение с подкреплением                                Генеративные модели в машинном обучении      Компьютерное зрение                          DevOps     2
# ...

# %% [markdown]
# Для читаемого варианта снова воспользуемся циклом (!СНОВА НЕ БЕЙТЕ!)

# %%
for key, value in groups_simillar_courses.iteritems():
    print("Для набора:\n" + str(key) + "\nКоличество значений: " + str(value) + "\n")
# Out:
# Для набора:
# ('Statistical Learning Theory', 'Анализ неструктурированных данных', 'Сбор и обработка данных с помощью краудсорсинга', 'Обучение с подкреплением', 'Конфликты и кооперация', 'Компьютерное зрение', 'DevOps')
# Количество значений: 2
#
# Для набора:
# ('Байесовские методы машинного обучения', 'Анализ неструктурированных данных', 'Глубинное обучение в обработке звука', 'Обучение с подкреплением', 'Генеративные модели в машинном обучении', 'Компьютерное зрение', 'DevOps')
# Количество значений: 2
#
# Для набора:
# ('Байесовские методы машинного обучения', 'Анализ неструктурированных данных', 'Сбор и обработка данных с помощью краудсорсинга', 'Обучение с подкреплением', 'Компьютерное зрение', 'Генеративные модели в машинном обучении', 'DevOps')
# Количество значений: 2
#
# Для набора:
# ...

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
# your code
def get_common_courses(group):
    common_courses_columns_labels = ["fall_1", "fall_2", "fall_3", "spring_1", "spring_2", "spring_3"]
    data_17_year = data.loc[data[group] != 0]
    common_courses = numpy.concatenate(data_17_year[common_courses_columns_labels].values, axis=0)
    common_courses_unique = numpy.unique(common_courses)
    return common_courses_unique

common_courses_17 = get_common_courses("17_group")
common_courses_18 = get_common_courses("18_group")
intersection = numpy.intersect1d(common_courses_17, common_courses_18, assume_unique=True)
print("Курсы, на которые записывались студенты обоих годов:\n " + numpy.array_str(intersection)[1:-1])
print("Таких курсов: " + str(intersection.shape[0]))
# Out:
# Курсы, на которые записывались студенты обоих годов:
#  'Statistical Learning Theory' 'Безопасность компьютерных систем'
#  'Высокопроизводительные вычисления' 'Моделирование временных рядов'
#  'Принятие решений в условиях риска и неопределённости'
#  'Сбор и обработка данных с помощью краудсорсинга' 'Численные методы'
# Таких курсов: 7

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
print("Курсы, выбранные только 3 курсом: " + str(numpy.setdiff1d(common_courses_18, common_courses_17))[1:-1])
print()
print("Курсы, выбранные только 4 курсом: " + str(numpy.setdiff1d(common_courses_17, common_courses_18))[1:-1])
# Out:
# Курсы, выбранные только 3 курсом: 'Анализ данных в бизнесе' 'Дискретная оптимизация'
#  'Дополнительные главы прикладной статистики' 'Компьютерные сети'
#  'Матричные вычисления' 'Машинное обучение 2'
#  'Промышленное программирование на языке Java' 'Системы баз данных'
#  'Теория баз данных' 'Язык SQL'
#
# Курсы, выбранные только 4 курсом: 'Анализ неструктурированных данных'
#  'Байесовские методы машинного обучения'
#  'Генеративные модели в машинном обучении'
#  'Глубинное обучение в обработке звука' 'Компьютерное зрение'
#  'Конфликты и кооперация' 'Методы сжатия и передачи медиаданных'
#  'Обучение с подкреплением'
#  'Проектирование и разработка высоконагруженных сервисов'
#  'Символьные вычисления'

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
# your code
rating_timestamp = data[["rating", "timestamp"]]
rating_timestamp.insert(2, "date", pd.to_datetime(rating_timestamp["timestamp"]).dt.strftime('%d-%m'))
rating_timestamp.drop("timestamp", axis=1)
rating_groupedby_date = rating_timestamp.groupby("date").mean()
fig, ax = plt.subplots()
ax.plot(rating_groupedby_date)

ax.set(xlabel='Дата', ylabel='Рейтинг',
       title='Средний рейтинг по дням получения ответов')
ax.grid()
fig.set_figwidth(20)
fig.set_figheight(10)
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
fig.savefig("mean-rating-by-day.pdf")

# %% [markdown]
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.

# %% [markdown]
# Ссылка на источник (базовый конфиг графика) : https://matplotlib.org/3.3.2/gallery/lines_bars_and_markers/simple_plot.html#sphx-glr-gallery-lines-bars-and-markers-simple-plot-py

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно.
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Формат csv: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * 181, 182 - МОП; 183 - ТИ; 184 - АДИС; 185, 186 - РС; 187 - АПР; 188 - МИ
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
df = data.copy()
assert df.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
data_courses_count = data.copy()
groups_array = numpy.array([171, 172, 173])

def two_courses_condition(group, is_mi):
    return numpy.where(numpy.logical_or(numpy.in1d(group, groups_array), is_mi), 2, 1)

data_courses_count['courses_count'] = two_courses_condition(data_courses_count["17_group"], data_courses_count["is_mi"])

# Обрабатываем нехорошего человека, поставившего аж три одинаковые дисциплины!
data_courses_count.loc[data_courses_count["id"] == "e0fceae1e285f737630bb6123a1bd85d", ["fall_2", "fall_3"]] = pd.Series([numpy.nan, numpy.nan])

# %% [markdown]
# Проверка:

# %%
col_name = "courses_count"    # insert your new column name as str

assert(data_courses_count[data_courses_count['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(data_courses_count[data_courses_count['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(data_courses_count[data_courses_count['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(data_courses_count[data_courses_count['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# Объявим словарь "бизнес-правил"

# %%
courses_capacity = {
    'Statistical Learning Theory' : 60,
    'Безопасность компьютерных систем' : 30,
    'Высокопроизводительные вычисления' : 60,
    'Моделирование временных рядов': 30,
    'Принятие решений в условиях риска и неопределённости': 30,
    'Сбор и обработка данных с помощью краудсорсинга': 30,
    'Численные методы': 30,
    'Анализ данных в бизнесе': 30,
    'Дискретная оптимизация': 30,
    'Дополнительные главы прикладной статистики': 30, 
    'Компьютерные сети': 30,
    'Матричные вычисления': 30, 
    'Машинное обучение 2': 30,
    'Промышленное программирование на языке Java': 30, 
    'Системы баз данных': 30,
    'Теория баз данных': 30, 
    'Язык SQL': 30,
    'Анализ неструктурированных данных': 1000,
    'Байесовские методы машинного обучения': 30,
    'Генеративные модели в машинном обучении': 30,
    'Глубинное обучение в обработке звука': 30, 
    'Компьютерное зрение': 30,
    'Конфликты и кооперация': 30, 
    'Методы сжатия и передачи медиаданных': 30,
    'Обучение с подкреплением': 30,
    'Проектирование и разработка высоконагруженных сервисов': 30,
    'Символьные вычисления': 30
}

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
data_column_labels = ["fall_1", "id", "percentile"]
bucket_column_labels = ["course", "id", "percentile"]
data_courses_count["is_first_place"] = False
data_courses_count["is_last_place"] = False

# добавляем в корзину все курсы первого приоритета
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count[data_column_labels]
# добавляем в корзину курсы второго приоритета для студентов, которые должны выбрать два курса
bucket_appendix = pd.DataFrame(columns = bucket_column_labels)
bucket_appendix[bucket_column_labels] = data_courses_count.loc[data_courses_count["courses_count"] == 2, ["fall_2", "id", "percentile"]]
bucket_appended = pd.concat([bucket, bucket_appendix])

# группируем по курсу
grouped_bucket = bucket_appended.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course"])  

for name, group in grouped_bucket:
    capacity = courses_capacity[name]
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    # выберем n лучших заявок
    group = group.drop_duplicates("id")
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course"]]
    print("Зачисляем: " + str(confirmed_students.shape[0]))
    # зачислим студентов на дисциплину
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])
    # для последующей проверки
    data_courses_count.loc[data_courses_count["id"] == confirmed_students.iloc[-1, 0], "is_last_place"] = True
    data_courses_count.loc[data_courses_count["id"] == confirmed_students.iloc[0, 0], "is_first_place"] = True


# Оставляем в первом датасете только "первые" курсы
course_1 = id_course.drop_duplicates("id")

# Во втором датасете оставим только те курсы, которые были "вторыми" для каждого id
course_2 = id_course.loc[id_course.duplicated("id")]
course_1.columns = ["id", "course_1"]
course_2.columns = ["id", "course_2"]

# Сольем курсы по id
courses = pd.merge(course_1, course_2, on="id", how="left")
data_courses_count = pd.merge(data_courses_count, courses, on="id", how="left")
data_courses_count = data_courses_count.fillna("")
# Out:
# В курсе Statistical Learning Theory осталось 60 свободных мест
# Зачисляем: 33
# В курсе Анализ неструктурированных данных осталось 1000 свободных мест
# Зачисляем: 48
# В курсе Байесовские методы машинного обучения осталось 30 свободных мест
# Зачисляем: 24
# В курсе Безопасность компьютерных систем осталось 30 свободных мест
# Зачисляем: 30
# В курсе Высокопроизводительные вычисления осталось 60 свободных мест
# Зачисляем: 44
# В курсе Глубинное обучение в обработке звука осталось 30 свободных мест
# Зачисляем: 23
# В курсе Матричные вычисления осталось 30 свободных мест
# Зачисляем: 15
# В курсе Моделирование временных рядов осталось 30 свободных мест
# Зачисляем: 30
# В курсе Принятие решений в условиях риска и неопределённости осталось 30 свободных мест
# Зачисляем: 8
# В курсе Сбор и обработка данных с помощью краудсорсинга осталось 30 свободных мест
# Зачисляем: 30
# В курсе Теория баз данных осталось 30 свободных мест
# Зачисляем: 14
# ...

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')
check_df
# Out:
#                    timestamp                                id  rating  \
# 0    2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1    2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2    2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3    2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4    2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                       ...                               ...     ...
# 342  2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 343  2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 344  2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 345  2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 346  2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
df = data_courses_count.copy()
df = df.sort_index().sort_index(axis=1)
check_df = check_df.sort_index().sort_index(axis=1)
df = df.drop(["course_1", "course_2", "courses_count"], axis=1)
df.loc[df["is_last_place"] == True]
df.to_csv('df.csv')

# %%
fir_col_name =  "is_first_place"    # insert name of your new column with is_first_place as str
last_col_name = "is_last_place"      # insert name of your new column with is_last_place as str
print(df.columns)
print(check_df.columns)
print(df.shape)
print(check_df.shape)

assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       == 
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# Index(['17_group', '18_group', 'blended', 'fall_1', 'fall_2', 'fall_3', 'id',
#        'is_first_place', 'is_first_time', 'is_last_place', 'is_mi',
#        'is_ml_student', 'percentile', 'rating', 'spring_1', 'spring_2',
#        'spring_3', 'timestamp'],
#       dtype='object')
# Index(['17_group', '18_group', 'blended', 'fall_1', 'fall_2', 'fall_3', 'id',
#        'is_first_place', 'is_first_time', 'is_last_place', 'is_mi',
#        'is_ml_student', 'percentile', 'rating', 'spring_1', 'spring_2',
#        'spring_3', 'timestamp'],
#       dtype='object')
# (347, 18)
# (347, 18)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-330-04ed60d160c0> in <module>
#       8 assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       9         ==
# ...

# %% [markdown]
# Датасеты идентичны по размерности и индексами, а также по содержимому (проверено вручную). Можно сделать вывод о недостаточной универсальности предложенных проверок

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %% [markdown]
# Распределяем вторую волну

# %%
# (￣^￣)ゞ
data_column_labels = ["fall_2", "id", "percentile", "courses_count"]
bucket_column_labels = ["course", "id", "percentile", "courses_count"]

# добавляем в корзину все курсы второго приоритета для тех, кто выбирает один курс и при этом не получил его
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), data_column_labels]

# добавляем в корзину курсы третьего приоритета для студентов, которые должны выбрать два курса и не получили второго курса
bucket_appendix = pd.DataFrame(columns = bucket_column_labels)
bucket_appendix[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_2"] == ""), ["fall_3", "id", "percentile", "courses_count"]]
bucket_appended = pd.concat([bucket, bucket_appendix])
bucket_appended

# группируем по курсу
grouped_bucket = bucket_appended.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course", "courses_count"])  

for name, group in grouped_bucket:
    if (name == ""): 
        continue
    capacity = courses_capacity[name]
    # выберем n лучших заявок
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course", "courses_count"]]
    confirmed_students = confirmed_students.drop_duplicates("id")
    # зачислим студентов на дисциплину
    print("Зачислено: " + str(confirmed_students.shape[0]))
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])

# Сливаем "добравших" первый курс
first_course = id_course.loc[id_course["courses_count"] == 1]
first_course = first_course.drop("courses_count", axis=1)
first_course.columns = ["id", "course_1"]
data_courses_count = pd.merge(data_courses_count, first_course, on="id", how="left")


# Сливаем "добравших" второй курс
second_course = id_course.loc[id_course["courses_count"] == 2]
second_course = second_course.drop("courses_count", axis=1)
second_course.columns = ["id", "course_2"]
data_courses_count = pd.merge(data_courses_count, second_course, on="id", how="left")

# Очистим таблицу от ненужных столбцов
data_courses_count["course_1"] = data_courses_count['course_1_y'].fillna(data_courses_count['course_1_x'])
data_courses_count["course_2"] = data_courses_count['course_2_y'].fillna(data_courses_count['course_2_x'])
data_courses_count = data_courses_count.drop(["course_1_x", "course_1_y", "course_2_x", "course_2_y"], axis = 1)
data_courses_count.to_csv("test.csv", index=None)
# Out:
# В курсе Statistical Learning Theory осталось 27 свободных мест
# Зачислено: 8
# В курсе Анализ неструктурированных данных осталось 952 свободных мест
# Зачислено: 5
# В курсе Байесовские методы машинного обучения осталось 6 свободных мест
# Зачислено: 1
# В курсе Безопасность компьютерных систем осталось 0 свободных мест
# Зачислено: 0
# В курсе Высокопроизводительные вычисления осталось 16 свободных мест
# Зачислено: 16
# В курсе Глубинное обучение в обработке звука осталось 7 свободных мест
# Зачислено: 7
# В курсе Матричные вычисления осталось 15 свободных мест
# Зачислено: 9
# В курсе Моделирование временных рядов осталось 0 свободных мест
# Зачислено: 0
# В курсе Принятие решений в условиях риска и неопределённости осталось 22 свободных мест
# Зачислено: 1
# В курсе Сбор и обработка данных с помощью краудсорсинга осталось 0 свободных мест
# Зачислено: 0
# В курсе Теория баз данных осталось 16 свободных мест
# Зачислено: 4
# В курсе Язык SQL осталось 1 свободных мест
# ...

# %% [markdown]
# Распределяем третью волну

# %%
data_column_labels = ["fall_3", "id", "percentile"]
bucket_column_labels = ["course", "id", "percentile"]

# добавляем в корзину все курсы второго приоритета для тех, кто выбирает один курс и при этом не получил его
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), data_column_labels]

# группируем по курсу
grouped_bucket = bucket.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course"])  

for name, group in grouped_bucket:
    if (name == numpy.nan): 
        continue
    capacity = courses_capacity[name]
    # выберем n лучших заявок
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course"]]
    confirmed_students = confirmed_students.drop_duplicates("id")
    # зачислим студентов на дисциплину
    print("Зачислено: " + str(confirmed_students.shape[0]))
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])

id_course.columns = ["id", "course_1"]
# Сливаем "добравших" первый курс
data_courses_count = pd.merge(data_courses_count, id_course, on="id", how="left")

data_courses_count["course_1"] = data_courses_count['course_1_y'].fillna(data_courses_count['course_1_x'])
data_courses_count = data_courses_count.drop(["course_1_x", "course_1_y"], axis = 1)
data_courses_count[["id", "course_1", "course_2"]]
# Out:
# В курсе Statistical Learning Theory осталось 19 свободных мест
# Зачислено: 2
# В курсе Анализ неструктурированных данных осталось 947 свободных мест
# Зачислено: 3
# В курсе Высокопроизводительные вычисления осталось 0 свободных мест
# Зачислено: 0
# В курсе Матричные вычисления осталось 6 свободных мест
# Зачислено: 6
# В курсе Моделирование временных рядов осталось 0 свободных мест
# Зачислено: 0
# В курсе Принятие решений в условиях риска и неопределённости осталось 21 свободных мест
# Зачислено: 1
# В курсе Сбор и обработка данных с помощью краудсорсинга осталось 0 свободных мест
# Зачислено: 0
# В курсе Теория баз данных осталось 12 свободных мест
# Зачислено: 6
# В курсе Язык SQL осталось 0 свободных мест
# Зачислено: 0
#                                    id  \
# 0    93ff79a51cd602f1dd3028ba2c129503
# 1    26b01b1c4cd5656bab18d24c548834fb
# 2    30f3653fc176d54e89ac3179c455c6dd
# 3    1528f0eaa027580820ccf0d92a53ad68
# 4    496ea4f0d4abe264b1bb1b80eb3830c5
# ...

# %%
idx = (data_courses_count["course_2"] != "") & (data_courses_count["course_1"] == "")

# подменяем случай, когда единственный из двух возможных курсов был записан в второй столбец (если он был выбран на второй волне)
data_courses_count.loc[idx, ["course_2", "course_1"]] = data_courses_count.loc[idx, ["course_1", "course_2"]].values

data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), "course_1"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_1"] == ""), "course_1"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_2"] == ""), "course_2"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 1), "course_2"] = "-"

# %%
export_data = data_courses_count[["id", "course_1", "course_2"]]
export_data.columns = ["ID", "course1", "course2"]
export_data.to_csv("res_fall.csv", index=None)

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (https://contest.yandex.ru/contest/19782/problems/A/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# Ссылка на успешное решение: https://contest.yandex.ru/contest/19782/run-report/35708514/

# %% [markdown]
# *Дисклеймер:*
#
# Контест выдаётся для самопроверки. Если ваша посылка получила ОК, то код, скорее всего, правильный. Но при этом оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# **Дополнительное задание. [2 бонусных балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.**
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %% [markdown]
# Определим количество курсов:

# %% [markdown]
# Добавим признак - количество весенних курсов

# %%
# (￣^'￣)ゞ
data_courses_count = data.copy()
groups_array = numpy.array([171, 172, 173])

def two_courses_condition_spring(group):
    return numpy.where(numpy.in1d(group, groups_array), 2, 1)

data_courses_count['courses_count'] = two_courses_condition_spring(data_courses_count["17_group"])

# %% [markdown]
# Объявим словарь бизнес-правил для весенних курсов

# %%
courses_capacity = {
    'Statistical Learning Theory' : 30,
    'Безопасность компьютерных систем' : 30,
    'Высокопроизводительные вычисления' : 30,
    'Моделирование временных рядов': 30,
    'Принятие решений в условиях риска и неопределённости': 30,
    'Сбор и обработка данных с помощью краудсорсинга': 30,
    'Численные методы': 30,
    'Анализ данных в бизнесе': 60,
    'Дискретная оптимизация': 30,
    'Дополнительные главы прикладной статистики': 30, 
    'Компьютерные сети': 30,
    'Матричные вычисления': 30, 
    'Машинное обучение 2': 30,
    'Промышленное программирование на языке Java': 30, 
    'Системы баз данных': 30,
    'Теория баз данных': 30, 
    'Язык SQL': 30,
    'Анализ неструктурированных данных': 30,
    'Байесовские методы машинного обучения': 30,
    'Генеративные модели в машинном обучении': 30,
    'Глубинное обучение в обработке звука': 30, 
    'Компьютерное зрение': 30,
    'Конфликты и кооперация': 30, 
    'Методы сжатия и передачи медиаданных': 30,
    'Обучение с подкреплением': 60,
    'Проектирование и разработка высоконагруженных сервисов': 30,
    'Символьные вычисления': 30
}

# %% [markdown]
# Немного предварительной обработки

# %%
# Убираем господ из МОП, выбравших МО-2
idx = (data_courses_count['17_group'] == 172) | (data_courses_count['17_group'] == 171) | (data_courses_count['18_group'] == 181) | (data_courses_count['18_group'] == 182)
data_courses_count.loc[idx  & (data_courses_count['spring_3'] == 'Машинное обучение 2'), "spring_3"] = ""
data_courses_count.loc[idx  & (data_courses_count['spring_2'] == 'Машинное обучение 2'), "spring_2"] = ""
data_courses_count.loc[idx  & (data_courses_count['spring_1'] == 'Машинное обучение 2'), "spring_1"] = ""

# %% [markdown]
# Проведем первую волну отбора

# %%
data_column_labels = ["spring_1", "id", "percentile"]
bucket_column_labels = ["course", "id", "percentile"]

# добавляем в корзину все курсы первого приоритета
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count[data_column_labels]

# добавляем в корзину курсы второго приоритета для студентов, которые должны выбрать два курса
bucket_appendix = pd.DataFrame(columns = bucket_column_labels)
bucket_appendix[bucket_column_labels] = data_courses_count.loc[data_courses_count["courses_count"] == 2, ["spring_2", "id", "percentile"]]
bucket_appended = pd.concat([bucket, bucket_appendix])

# группируем по курсу
grouped_bucket = bucket_appended.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course"])  

for name, group in grouped_bucket:
    if (name == ""):
        continue
    capacity = courses_capacity[name]
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    # выберем n лучших заявок
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course"]]
    confirmed_students = confirmed_students.drop_duplicates("id")
    print("Зачисляем: " + str(confirmed_students.shape[0]))
    # зачислим студентов на дисциплину
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])


# Оставляем в первом датасете только "первые" курсы
course_1 = id_course.drop_duplicates("id")

# Во втором датасете оставим только те курсы, которые были "вторыми" для каждого id
course_2 = id_course.loc[id_course.duplicated("id")]
course_1.columns = ["id", "course_1"]
course_2.columns = ["id", "course_2"]

# Сольем курсы по id
courses = pd.merge(course_1, course_2, on="id", how="left")
data_courses_count = pd.merge(data_courses_count, courses, on="id", how="left")
data_courses_count = data_courses_count.fillna("")
# Out:
# В курсе Анализ данных в бизнесе осталось 60 свободных мест
# Зачисляем: 19
# В курсе Генеративные модели в машинном обучении осталось 30 свободных мест
# Зачисляем: 16
# В курсе Дискретная оптимизация осталось 30 свободных мест
# Зачисляем: 30
# В курсе Дополнительные главы прикладной статистики осталось 30 свободных мест
# Зачисляем: 11
# В курсе Компьютерное зрение осталось 30 свободных мест
# Зачисляем: 29
# В курсе Компьютерные сети осталось 30 свободных мест
# Зачисляем: 30
# В курсе Конфликты и кооперация осталось 30 свободных мест
# Зачисляем: 19
# В курсе Машинное обучение 2 осталось 30 свободных мест
# Зачисляем: 25
# В курсе Методы сжатия и передачи медиаданных осталось 30 свободных мест
# Зачисляем: 22
# В курсе Обучение с подкреплением осталось 60 свободных мест
# Зачисляем: 60
# В курсе Проектирование и разработка высоконагруженных сервисов осталось 30 свободных мест
# Зачисляем: 29
# В курсе Промышленное программирование на языке Java осталось 30 свободных мест
# ...

# %% [markdown]
# Проведем вторую волну отбора

# %%
# (￣^￣)ゞ
data_column_labels = ["spring_2", "id", "percentile", "courses_count"]
bucket_column_labels = ["course", "id", "percentile", "courses_count"]

# добавляем в корзину все курсы второго приоритета для тех, кто выбирает один курс и при этом не получил его
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), data_column_labels]

# добавляем в корзину курсы третьего приоритета для студентов, которые должны выбрать два курса и не получили второго курса
bucket_appendix = pd.DataFrame(columns = bucket_column_labels)
bucket_appendix[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_2"] == ""), ["spring_3", "id", "percentile", "courses_count"]]
bucket_appended = pd.concat([bucket, bucket_appendix])
bucket_appended

# группируем по курсу
grouped_bucket = bucket_appended.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course", "courses_count"])  

for name, group in grouped_bucket:
    if (name == ""):
        continue
    capacity = courses_capacity[name]
    # выберем n лучших заявок
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course", "courses_count"]]
    confirmed_students = confirmed_students.drop_duplicates("id")
    # зачислим студентов на дисциплину
    print("Зачислено: " + str(confirmed_students.shape[0]))
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])

# Сливаем "добравших" первый курс
first_course = id_course.loc[id_course["courses_count"] == 1]
first_course = first_course.drop("courses_count", axis=1)
first_course.columns = ["id", "course_1"]
data_courses_count = pd.merge(data_courses_count, first_course, on="id", how="left")


# Сливаем "добравших" второй курс
second_course = id_course.loc[id_course["courses_count"] == 2]
second_course = second_course.drop("courses_count", axis=1)
second_course.columns = ["id", "course_2"]
data_courses_count = pd.merge(data_courses_count, second_course, on="id", how="left")

# Очистим таблицу от ненужных столбцов
data_courses_count["course_1"] = data_courses_count['course_1_y'].fillna(data_courses_count['course_1_x'])
data_courses_count["course_2"] = data_courses_count['course_2_y'].fillna(data_courses_count['course_2_x'])
data_courses_count = data_courses_count.drop(["course_1_x", "course_1_y", "course_2_x", "course_2_y"], axis = 1)
data_courses_count.to_csv("test.csv", index=None)
# Out:
# В курсе Анализ данных в бизнесе осталось 41 свободных мест
# Зачислено: 8
# В курсе Генеративные модели в машинном обучении осталось 14 свободных мест
# Зачислено: 2
# В курсе Дискретная оптимизация осталось 0 свободных мест
# Зачислено: 0
# В курсе Дополнительные главы прикладной статистики осталось 19 свободных мест
# Зачислено: 4
# В курсе Компьютерное зрение осталось 1 свободных мест
# Зачислено: 1
# В курсе Компьютерные сети осталось 0 свободных мест
# Зачислено: 0
# В курсе Конфликты и кооперация осталось 11 свободных мест
# Зачислено: 1
# В курсе Машинное обучение 2 осталось 5 свободных мест
# Зачислено: 5
# В курсе Методы сжатия и передачи медиаданных осталось 8 свободных мест
# Зачислено: 7
# В курсе Обучение с подкреплением осталось 0 свободных мест
# Зачислено: 0
# В курсе Промышленное программирование на языке Java осталось 0 свободных мест
# Зачислено: 0
# В курсе Символьные вычисления осталось 21 свободных мест
# Зачислено: 2
# ...

# %% [markdown]
# Проведем последнюю волну отбора

# %%
data_column_labels = ["spring_3", "id", "percentile"]
bucket_column_labels = ["course", "id", "percentile"]

# добавляем в корзину все курсы второго приоритета для тех, кто выбирает один курс и при этом не получил его
bucket = pd.DataFrame(columns = bucket_column_labels)
bucket[bucket_column_labels] = data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), data_column_labels]

# группируем по курсу
grouped_bucket = bucket.groupby("course")

# выбираем n лучших перцентелей для каждого курса
id_course = pd.DataFrame(columns = ["id", "course"])  

for name, group in grouped_bucket:
    if (name == ""):
        continue
    capacity = courses_capacity[name]
    # выберем n лучших заявок
    print("В курсе " + name + " осталось " + str(capacity) + " свободных мест")
    confirmed_students = group.loc[group["percentile"].nsmallest(capacity).index][["id", "course"]]
    confirmed_students = confirmed_students.drop_duplicates("id")
    # зачислим студентов на дисциплину
    print("Зачислено: " + str(confirmed_students.shape[0]))
    courses_capacity[name] -= confirmed_students.shape[0]
    id_course = pd.concat([id_course, confirmed_students])

id_course.columns = ["id", "course_1"]
# Сливаем "добравших" первый курс
data_courses_count = pd.merge(data_courses_count, id_course, on="id", how="left")

data_courses_count["course_1"] = data_courses_count['course_1_y'].fillna(data_courses_count['course_1_x'])
data_courses_count = data_courses_count.drop(["course_1_x", "course_1_y"], axis = 1)
data_courses_count[["id", "course_1", "course_2"]]
# Out:
# В курсе Анализ данных в бизнесе осталось 33 свободных мест
# Зачислено: 5
# В курсе Дискретная оптимизация осталось 0 свободных мест
# Зачислено: 0
# В курсе Дополнительные главы прикладной статистики осталось 15 свободных мест
# Зачислено: 2
# В курсе Компьютерные сети осталось 0 свободных мест
# Зачислено: 0
# В курсе Машинное обучение 2 осталось 0 свободных мест
# Зачислено: 0
# В курсе Проектирование и разработка высоконагруженных сервисов осталось 1 свободных мест
# Зачислено: 1
# В курсе Системы баз данных осталось 19 свободных мест
# Зачислено: 6
# В курсе Численные методы осталось 16 свободных мест
# Зачислено: 2
#                                    id                              course_1  \
# 0    93ff79a51cd602f1dd3028ba2c129503                Дискретная оптимизация
# 1    26b01b1c4cd5656bab18d24c548834fb                Дискретная оптимизация
# 2    30f3653fc176d54e89ac3179c455c6dd                Дискретная оптимизация
# ...

# %%
idx = (data_courses_count["course_2"] != "") & (data_courses_count["course_1"] == "")

# подменяем случай, когда единственный из двух возможных курсов был записан в второй столбец (если он был выбран на второй волне)
data_courses_count.loc[idx, ["course_2", "course_1"]] = data_courses_count.loc[idx, ["course_1", "course_2"]].values

data_courses_count.loc[(data_courses_count["courses_count"] == 1) & (data_courses_count["course_1"] == ""), "course_1"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_1"] == ""), "course_1"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 2) & (data_courses_count["course_2"] == ""), "course_2"] = "???"
data_courses_count.loc[(data_courses_count["courses_count"] == 1), "course_2"] = "-"

export_data = data_courses_count[["id", "course_1", "course_2"]]
export_data.columns = ["ID", "course1", "course2"]
export_data.to_csv("res_spring.csv", index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (https://contest.yandex.ru/contest/19782/problems/B/) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.**

# %% [markdown]
# Ссылка на наиболее "успешную" посылку: https://contest.yandex.ru/contest/19782/run-report/35711201/, ник Arseny Neustroev

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %% [markdown]
# [![Au-Of-NB7yt-0.jpg](https://i.postimg.cc/ydRq3sSn/Au-Of-NB7yt-0.jpg)](https://postimg.cc/BLJ7dWp1)

# %% [markdown]
# К сожалению, половина времени уходит не на работу с фреймворком, а на войну с неопределенными бизнес-правилами (переход приоритетов, неточно сформулированные критерии и пр.). Это досадно
